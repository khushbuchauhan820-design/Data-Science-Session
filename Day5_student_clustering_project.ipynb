# %% [markdown]
# <a href="https://colab.research.google.com/github/khushbuchauhan820-design/Data-Science-Session/blob/main/Day5_student_clustering_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step 1: Import Libries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
np.random.seed(42)

data = pd.DataFrame({
    "hours_studied": np.random.randint(1, 10, 50),
    "attendence": np.random.randint(50, 100, 50),

})

data.head()
# Out:
#    hours_studied  attendence
# 0              7          53
# 1              4          51
# 2              8          55
# 3              5          91
# 4              7          53

# %%
x = data[["hours_studied", "attendence"]]

model = KMeans(n_clusters=3, random_state=42, n_init=10)
data["cluster"] = model.fit_predict(x)

data.head()
# Out:
#    hours_studied  attendence  cluster
# 0              7          53        1
# 1              4          51        1
# 2              8          55        1
# 3              5          91        0
# 4              7          53        1

# %%
score = silhouette_score(x, data["cluster"])
print("silhoutte score:", score)
# Out:
# silhoutte score: 0.5276411515754762

# %%
plt.scatter(data["hours_studied"], data["attendence"], c=data["cluster"])

centers = model.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], marker='x', s=200)

plt.xlabel("Hours Studied")
plt.ylabel("Attendence")
plt.title("Student Segmentation")
plt.show()

# %%
#Example: New student
#hours_studied = 6, attendence = 80

new_student = [[6, 80]]

predicted_cluster = model.predict(new_student)

print("New student belong to Cluster:", predicted_cluster[0])
# Out:
# New student belong to Cluster: 2
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
